# %%
import pandas as pd
import numpy as np
import seaborn as sns
from plot_helper import remove_rank, calculate_wall_clock_time_thresholds, calculate_lengths_achieved, create_population_barplot
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %%
data_frames = {
    "a280"  : "population_test_a280_Jan_05_194151.gz",
    "d1291" : "population_test_d1291_Jan_09_172740.gz",
    "u2319" : "population_test_u2319_final.gz"
}

# Color map for population plots
cmap = "plasma"

# %% [markdown]
# # a280

# %%
df = pd.read_csv(data_frames["a280"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df, thresholds)
create_population_barplot(line_df, "a280", thresholds, palette=cmap)

# %% [markdown]
# # d1291

# %%
df = pd.read_csv(data_frames["d1291"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df, thresholds)
create_population_barplot(line_df, "d1291", thresholds, palette=cmap)

# %% [markdown]
# # u2319

# %%
df = pd.read_csv(data_frames["u2319"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df, thresholds)
create_population_barplot(line_df, "u2319", thresholds, palette=cmap)
