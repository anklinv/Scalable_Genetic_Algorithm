# %%
import pandas as pd
import numpy as np
import seaborn as sns
from plot_helper import remove_rank, calculate_wall_clock_time_thresholds, calculate_lengths_achieved, create_population_barplot, create_scaling_lineplot
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %%
data_frames = {
    "a280"  : "population_test_a280_final.gz",
    "d1291" : "population_test_d1291_final.gz",
    "u2319" : "population_test_u2319_final.gz",
    "bier127" : "population_test_bier127_final.gz"
}

# Color map for population plots
cmap = "plasma"

figsize=(8,4)

# %% [markdown]
# # a280

# %%
df = pd.read_csv(data_frames["a280"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df, thresholds)
create_population_barplot(line_df, "a280", thresholds, palette=cmap, figsize=figsize)

# %% [markdown]
# # d1291

# %%
df = pd.read_csv(data_frames["d1291"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df, thresholds)
create_population_barplot(line_df, "d1291", thresholds, palette=cmap, figsize=figsize)

# %% [markdown]
# # u2319

# %%
df = pd.read_csv(data_frames["u2319"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df, thresholds)
create_population_barplot(line_df, "u2319", thresholds, palette=cmap, figsize=figsize)

# %% [markdown]
# # bier127
# Just for fun

# %%
df = pd.read_csv(data_frames["bier127"])
thresholds = calculate_wall_clock_time_thresholds(df)
line_df = calculate_lengths_achieved(df[df["population"] > 3], thresholds)
create_population_barplot(line_df, "bier127", thresholds, palette=cmap, figsize=figsize)

# %%
line_df["mode"] = ""
create_scaling_lineplot(line_df[line_df['population'].isin([4, 16, 128, 1024, 4096, 8192, 16384, 32768, 65536, 131072])], "bier127",
                        limits=True, ylow=120000, yhigh=200000,
                        manual_legend=True, legend_n=[4, 16, 128, 1024, 4096, 8192, 16384, 32768, 65536, 131072], legend_col=2, 
                        hue="population", palette=cmap, figsize=(8, 5))
